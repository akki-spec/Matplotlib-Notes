# %%
import matplotlib.pyplot as plt
import numpy as np

#scatter graph = shows the relationship between two variables
#                helps to identify a correlation (+, -, None)
#                Example: study hours vs. Test scores

# %%
x = [0,1,1,2,3,4,4,3,6,7,5]# hours studied
y = [0,20,25,40,60,50,65,80,70,60,85] # marks scored

plt.scatter(x,y)
plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Hours vs Marks')

# %%
x = [0,1,1,2,3,4,4,3,6,7,5]# hours studied
y = [0,20,25,40,60,50,65,80,70,60,85] # marks scored

plt.scatter(x,y,color = 'skyblue',
            alpha = 0.5)#tranparency

plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Hours vs Marks')

# %%
x = [0,1,1,2,3,4,4,3,6,7,5]# hours studied
y = [0,20,25,40,60,50,65,80,70,60,85] # marks scored

plt.scatter(x,y,color = 'skyblue',
            alpha = 0.5,
            s = 200)#alpha - tranparency, s - size

plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Hours vs Marks')

# %%
x = [0,1,1,2,3,4,4,3,6,7,5]# hours studied
y = [0,20,25,40,60,50,65,80,70,60,85] # marks scored

x2 = [1,1,2,3,4,5,5,6,7,6,8]# hours studied
y2 = [20,23,43,64,52,65,81,75,64,85,75] # marks scored
#class1
plt.scatter(x,y,color = 'skyblue',
            alpha = 0.5,
            s = 200)#alpha - tranparency, s - size
#class2
plt.scatter(x2,y2,color = 'red',
            alpha = 0.5,
            s = 200)#alpha - tranparency, s - size


plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Hours vs Marks')
# Out:
# Text(0.5, 1.0, 'Hours vs Marks')

# %%
x = [0,1,1,2,3,4,4,3,6,7,5]# hours studied
y = [0,20,25,40,60,50,65,80,70,60,85] # marks scored

x2 = [1,1,2,3,4,5,5,6,7,6,8]# hours studied
y2 = [20,23,43,64,52,65,81,75,64,85,75] # marks scored

plt.scatter(x,y,color = 'skyblue',
            alpha = 0.5,
            s = 200,
            label = 'class A')

plt.scatter(x2,y2,color = 'red',
            alpha = 0.5,
            s = 200,
            label =  'Class B')


plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Hours vs Marks')

plt.legend(loc = 'upper left')
plt.show()
